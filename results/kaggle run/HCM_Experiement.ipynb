# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
# !git clone https://github.com/yas19sin/HCR-Bio-LLM.git
# %cd HCR-Bio-LLM
# Out:
# Cloning into 'HCR-Bio-LLM'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 165 (delta 36), reused 165 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (165/165), 26.40 MiB | 36.39 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /kaggle/working/HCR-Bio-LLM

# %%
# !pip -q install -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 93.9 MB/s eta 0:00:00:00:01:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
# !python train.py --config configs/smoke.yaml
# Out:
# event=start params=25888 device=cuda model_type=hcr_moment task=causal dataset_source=built-in fallback Shakespeare excerpt dataset_chars=329 dataset_fallback=True dataset_rows=None dataset_cache_path=None train_windows=262 val_windows=1
# event=train step=1 loss=3.8982 tokens_per_sec=250.9478 state_mu_mean=-0.0048 state_mu_std=1.0001 state_log_var_mean=-3.0022 state_log_var_std=0.0757 state_variance_mean=0.0498
# event=eval step=1 val_loss=3.7010 val_accuracy=0.0312 val_ece=0.1162 val_brier=0.9250 val_perplexity=40.4885 val_log_var_mean=-2.9981 val_log_var_std=0.0794 val_mu_mean=-0.0148 val_mu_std=0.9997 val_variance_mean=0.0500
# event=train step=2 loss=3.6730 tokens_per_sec=410.8109 state_mu_mean=-0.0045 state_mu_std=0.9998 state_log_var_mean=-2.9981 state_log_var_std=0.0789 state_variance_mean=0.0500
# event=train step=3 loss=3.5429 tokens_per_sec=607.5858 state_mu_mean=-0.0007 state_mu_std=0.9997 state_log_var_mean=-2.9950 state_log_var_std=0.0824 state_variance_mean=0.0502
# ...

# %%
# !python train.py --config configs/transformer_baseline.yaml
# Out:
# event=start params=825728 device=cuda model_type=transformer_baseline task=causal dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train#Text dataset_chars=1223296 dataset_fallback=False dataset_rows=472 dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# event=train step=1 loss=4.2924 tokens_per_sec=7008.2022 state_mu_mean=-0.0424 state_mu_std=0.9991
# event=eval step=1 val_loss=4.1701 val_accuracy=0.0301 val_ece=0.0207 val_brier=0.9641 val_perplexity=64.7236 val_mu_mean=-0.0528 val_mu_std=0.9984
# event=train step=25 loss=3.1736 tokens_per_sec=80693.1079 state_mu_mean=-0.1282 state_mu_std=0.9940
# event=train step=50 loss=2.8615 tokens_per_sec=122954.4035 state_mu_mean=-0.0962 state_mu_std=1.0022
# event=train step=75 loss=2.7574 tokens_per_sec=148665.4391 state_mu_mean=-0.0613 state_mu_std=1.0100
# ...

# %%
# !python sample.py --checkpoint runs/transformer_baseline/best.pt --prompt "First "
# Out:
# # checkpoint step: 5000
# First the bale.
#
# KING RICHARD II:
# What say, by wook this bame, nog, for
# Our set of hold, quint it not of make that this sent.
#
# SICINIUS:
# There consping all apmand my besingland.
#
# CLAUDIO:
# And emaws as that do
# proteming?
#
# Crine denemoth: prate, not thou was them! for I nam?
#
# PORIXENES:
# Servoit, by them he

# %%
# !python eval.py --checkpoint runs/transformer_baseline/best.pt
# Out:
# {
#   "accuracy": 0.48475341796875,
#   "brier": 0.5061684414744377,
#   "checkpoint_step": 5000,
#   "corrupted_loss": 2.1196144342422487,
#   "corruption_degradation": 1.2313789782909228,
#   "ece": 0.033090878091752526,
#   "loss": 1.7213339447975158,
#   "mu_mean": -0.03956588972359896,
#   "mu_std": 1.2052100002765656,
#   "perplexity": 5.591982887756892
# }

# %%
# !python analyze_uncertainty.py --checkpoint runs/transformer_baseline/best.pt
# Out:
# {
#   "checkpoint_step": 5000,
#   "mu_mean": -0.03547516204416752,
#   "mu_std": 1.2053935050964355
# }

# %%
# !python train.py --config configs/smoke_faithful_hcr.yaml
# Out:
# event=start params=9232 device=cuda model_type=hcr_blockwise_joint task=causal dataset_source=built-in fallback Shakespeare excerpt dataset_chars=329 dataset_fallback=True dataset_rows=None dataset_cache_path=None train_windows=262 val_windows=1
# ...

# %%
# !python hcr_synthetic_demo.py
# Out:
# {
#   "coeff_shape": [
#     6,
#     6
#   ],
#   "conditional_sample_mean": 0.5351920127868652,
#   "conditional_sample_std": 0.27757537364959717,
#   "conditional_y_mode_mse": 0.0004315118712838739,
#   "conditional_y_variance_mean": 0.0015069630462676287,
#   "degree": 5,
#   "forward_y_given_x_mse": 2.759426206466742e-05,
#   "marginal_x_coeff_shape": [
#     6
#   ],
#   "max_total_degree": null,
#   "noise": 0.03,
#   "nonzero_coefficients": 36,
#   "pairwise_mi_approx": 2.9312753677368164,
#   "propagation_coeff_max_abs_diff": 2.384185791015625e-07,
#   "propagation_mean_mse": 5.012492165922693e-16,
#   "propagation_variance_mse": 3.1314334250936613e-16,
#   "reverse_x_given_y_mse": 0.0014430799055844545,
#   "samples": 2048
# }

# %%
# !python hcr_faithfulness_check.py
# Out:
# {
#   "basis_gram_max_abs_error": 3.5762786865234375e-07,
#   "blockwise_carried_coeff_shape": [
#     2,
#     3,
#     4,
#     9
#   ],
#   "blockwise_carried_output_shape": [
#     2,
#     3,
#     8
#   ],
#   "blockwise_conditional_coeff_shape": [
#     2,
#     3,
#     4,
#     9
#   ],
#   "blockwise_mean_shape": [
#     2,
#     3,
#     8
#   ],
#   "blockwise_propagation_coeff_max_abs_diff": 0.0,
#   "blockwise_variance_min": 0.07976412773132324,
#   "blockwise_variance_shape": [
#     2,
#     3,
#     8
#   ],
#   "lm_density_coeff_shape": [
#     2,
#     8,
#     8,
#     9
#   ],
#   "lm_density_state_layers_shape": [
#     2,
#     2,
#     8,
#     8,
#     9
#   ],
#   "lm_has_hcr_state": true,
#   "lm_logits_shape": [
#     2,
#     8,
#     32
#   ],
#   "lm_loss_finite": true,
#   "lm_state_keys": [
#     "hcr_coeff_mean",
#     "hcr_coeff_std",
#     "hcr_conditional_coefficients",
#     "hcr_conditional_mean",
#     "hcr_conditional_variance",
# ...

# %%
# !python train.py --config configs/hcr_moment.yaml
# Out:
# event=start params=2675072 device=cuda model_type=hcr_moment task=causal dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train dataset_chars=1223296 dataset_fallback=False dataset_rows=None dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# event=train step=1 loss=4.8768 tokens_per_sec=6607.7887 state_mu_mean=-0.0397 state_mu_std=0.9992 state_log_var_mean=-2.9759 state_log_var_std=0.1822 state_variance_mean=0.0518
# event=eval step=1 val_loss=4.4201 val_accuracy=0.0291 val_ece=0.0520 val_brier=0.9603 val_perplexity=83.1048 val_log_var_mean=-2.9571 val_log_var_std=0.1840 val_mu_mean=-0.0593 val_mu_std=0.9982 val_variance_mean=0.0528
# event=train step=25 loss=3.2233 tokens_per_sec=53635.9200 state_mu_mean=-0.0609 state_mu_std=0.9990 state_log_var_mean=-2.7452 state_log_var_std=0.7160 state_variance_mean=0.0807
# ...

# %%
# !python sample.py --checkpoint runs/hcr_moment/best.pt --prompt "First "
# Out:
# # checkpoint step: 5000
# First Take rather?
# For you make forth out with his and law.
#
# KING RICHARD III:
# When I stance; and men, face, and come,
# Therefore not met fursul I, where noble it her gonest.
#
# VOLUMNIA:
# Which thou see and the alking. I good Worrink
# Shame we pressend; when thinks the execticion thy slave thee
# Thee brought y

# %%
# !python eval.py --checkpoint runs/hcr_moment/best.pt
# Out:
# {
#   "accuracy": 0.49674072265625,
#   "brier": 0.49680187553167343,
#   "checkpoint_step": 5000,
#   "corrupted_loss": 2.116483283042908,
#   "corruption_degradation": 1.258619291334903,
#   "ece": 0.030800470896065236,
#   "log_var_mean": -1.5860941648483275,
#   "log_var_std": 0.6500784009695053,
#   "loss": 1.6815913259983062,
#   "mu_mean": 0.010683470731601119,
#   "mu_std": 1.1583851456642151,
#   "perplexity": 5.3741011170874025,
#   "variance_mean": 0.24889918193221092
# }

# %%
# !python analyze_uncertainty.py --checkpoint runs/hcr_moment/best.pt
# Out:
# {
#   "checkpoint_step": 5000,
#   "log_var_mean": -1.6613147139549256,
#   "log_var_std": 0.6533742070198059,
#   "mu_mean": 0.011180800013244152,
#   "mu_std": 1.1586323857307435,
#   "variance_mean": 0.2314196988940239
# }

# %%
# !python train.py --config configs/hcr_density.yaml
# Out:
# event=start params=3284528 device=cuda model_type=hcr_density task=causal dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train dataset_chars=1223296 dataset_fallback=False dataset_rows=None dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# event=train step=1 loss=5.1717 tokens_per_sec=6239.2050 state_mu_mean=-0.0491 state_mu_std=0.9988 state_log_var_mean=-2.9925 state_log_var_std=0.1733 state_variance_mean=0.0509 state_basis_entropy=0.8627
# event=eval step=1 val_loss=4.5903 val_accuracy=0.0091 val_ece=0.0919 val_brier=0.9717 val_perplexity=98.5212 val_basis_entropy=1.8745 val_log_var_mean=-2.9707 val_log_var_std=0.1814 val_mu_mean=-0.0822 val_mu_std=0.9965 val_variance_mean=0.0521
# event=train step=25 loss=3.2810 tokens_per_sec=46383.9310 state_mu_mean=-0.1257 state_mu_std=0.9924 state_log_var_mean=-2.7382 state_log_var_std=0.8159 state_variance_mean=0.0862 state_basis_entropy=0.0000
# ...

# %%
# !python sample.py --checkpoint runs/hcr_density/best.pt --prompt "First "
# Out:
# # checkpoint step: 5000
# First me
# too, fair to sonding man, and this ore exforce
# Their words going be and deadures of before
# Leboune is other some to again his of our his eyes,
# So you have disgried ovour despresaget,
# To at with a my standischep!
# Then or sorramed,
# The heaven and to the lady; here are you,
# The care of you have eigh

# %%
# !!python eval.py --checkpoint runs/hcr_density/best.pt
# Out:
# ['{',
#  '  "accuracy": 0.50084228515625,',
#  '  "basis_entropy": 0.20312157049775123,',
#  '  "brier": 0.4909791678190231,',
#  '  "checkpoint_step": 5000,',
#  '  "corrupted_loss": 2.12761812210083,',
#  '  "corruption_degradation": 1.2721213130052087,',
#  '  "ece": 0.03012426495552063,',
#  '  "log_var_mean": -1.5796086609363555,',
#  '  "log_var_std": 0.6372876048088074,',
#  '  "loss": 1.672496247291565,',
#  '  "mu_mean": -0.017774848360568286,',
#  '  "mu_std": 1.1606156408786774,',
#  '  "perplexity": 5.325444846161614,',
#  '  "variance_mean": 0.24879204854369164',
#  '}']

# %%
# !python analyze_uncertainty.py --checkpoint runs/hcr_density/best.pt
# Out:
# {
#   "basis_entropy": 0.2147213563323021,
#   "checkpoint_step": 5000,
#   "log_var_mean": -1.6548623085021972,
#   "log_var_std": 0.6420980274677277,
#   "mu_mean": -0.016742297261953355,
#   "mu_std": 1.1604311108589171,
#   "variance_mean": 0.23149893432855606
# }

# %%
# !python train.py --config configs/hcr_joint_pairwise.yaml
# Out:
# event=start params=3243032 device=cuda model_type=hcr_joint_pairwise task=causal dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train dataset_chars=1223296 dataset_fallback=False dataset_rows=None dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# event=train step=1 loss=5.4655 tokens_per_sec=6508.6757 state_mu_mean=-0.0347 state_mu_std=0.9994 state_log_var_mean=-3.0027 state_log_var_std=0.1872 state_variance_mean=0.0505 state_corr_mean=0.0000 state_corr_std=1.0000
# event=eval step=1 val_loss=4.9460 val_accuracy=0.0093 val_ece=0.0691 val_brier=0.9761 val_perplexity=140.6176 val_corr_mean=0.0000 val_corr_std=1.0003 val_log_var_mean=-2.9725 val_log_var_std=0.1887 val_mu_mean=0.0032 val_mu_std=0.9998 val_variance_mean=0.0521
# ...

# %%
# !python sample.py --checkpoint runs/hcr_joint_pairwise/best.pt --prompt "First "
# Out:
# # checkpoint step: 10000
# First Gentleman, what is not his dagger.
#
# PAULINA:
# How to that come!
# Nay, sir, what for behold hate the full man! While even
# Of face or him, and good Romeo, parts good not love.
# Good-plushes these those wilt humaan!
# So worms beggar the fall of Buckingbroke a
# but wwill have heavy despate from Romeo finds
# D

# %%
# !python eval.py --checkpoint runs/hcr_joint_pairwise/best.pt
# Out:
# {
#   "accuracy": 0.54012451171875,
#   "brier": 0.4476366266608238,
#   "checkpoint_step": 10000,
#   "corr_mean": 0.0036425258964300155,
#   "corr_std": 1.3242076575756072,
#   "corrupted_loss": 2.0859407126903533,
#   "corruption_degradation": 1.3425733341004462,
#   "ece": 0.04051041342318058,
#   "log_var_mean": -1.106851762533188,
#   "log_var_std": 0.6286283135414124,
#   "loss": 1.5536884725093842,
#   "mu_mean": 0.027269369829446076,
#   "mu_std": 1.1007346391677857,
#   "perplexity": 4.728880399652938,
#   "variance_mean": 0.3959584891796112
# }

# %%
# !python analyze_uncertainty.py --checkpoint runs/hcr_joint_pairwise/best.pt
# Out:
# {
#   "checkpoint_step": 10000,
#   "corr_mean": 0.0032368145883083345,
#   "corr_std": 1.3224550008773803,
#   "log_var_mean": -1.1794189929962158,
#   "log_var_std": 0.6340473473072052,
#   "mu_mean": 0.027189850620925427,
#   "mu_std": 1.1003043055534363,
#   "variance_mean": 0.3695306062698364
# }

# %%
# !python train.py --config configs/hcr_blockwise_joint.yaml
# Out:
# event=start params=320768 device=cuda model_type=hcr_blockwise_joint task=causal dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train dataset_chars=1223296 dataset_fallback=False dataset_rows=None dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# ...

# %%
# !python sample.py --checkpoint runs/hcr_blockwise_joint/best.pt --prompt "First "
# Out:
# # checkpoint step: 5000
# First nenoe yow fertarst:
# Stiscuch whel un wordsidy livage doth to crock
# KIF that D His HAnd I frasting well a toed him.
#
# MERRCARET:
# Norigl ser lifcenter crobling to nither man'ss the this I that groost.
#
# MERES:
# Wherell thafut pleries not to Ef somelith were;
# This the here speited fear shencep's heasind;

# %%
# !python eval.py --checkpoint runs/hcr_blockwise_joint/best.pt
# Out:
# {
#   "accuracy": 0.4088623046875,
#   "brier": 0.5938217788934708,
#   "checkpoint_step": 5000,
#   "corrupted_loss": 2.221961200237274,
#   "corruption_degradation": 1.1179893877340892,
#   "ece": 0.026208081049844623,
#   "hcr_coeff_mean": 0.009998206980526447,
#   "hcr_coeff_std": 0.09436281770467758,
#   "hcr_conditional_coefficients_mean": 0.10060025379643775,
#   "hcr_conditional_coefficients_std": 49.227923679351804,
#   "hcr_conditional_mean_mean": 0.4997079372406006,
#   "hcr_conditional_mean_std": 0.1892093151807785,
#   "hcr_conditional_variance_mean": 0.24648137837648393,
#   "hcr_conditional_variance_std": 20.69079279899597,
#   "hcr_denominator_mean": 0.5305262997746467,
#   "hcr_denominator_std": 43.2472282409668,
#   "hcr_density_coefficients_mean": 0.10060025379643775,
#   "hcr_density_coefficients_std": 49.227923679351804,
#   "hcr_density_state_layers_mean": 0.09234835430979729,
#   "hcr_density_state_layers_std": 70.81705455780029,
# ...

# %%
# !python analyze_uncertainty.py --checkpoint runs/hcr_blockwise_joint/best.pt
# Out:
# {
#   "checkpoint_step": 5000,
#   "hcr_coeff_mean": 0.009998206980526447,
#   "hcr_coeff_std": 0.09436281770467758,
#   "hcr_conditional_coefficients_mean": 0.08400292508304119,
#   "hcr_conditional_coefficients_std": 51.23813018798828,
#   "hcr_conditional_mean_mean": 0.5000715881586075,
#   "hcr_conditional_mean_std": 0.18883623331785201,
#   "hcr_conditional_variance_mean": 0.24608695209026338,
#   "hcr_conditional_variance_std": 17.90932426452637,
#   "hcr_denominator_mean": 0.45582863688468933,
#   "hcr_denominator_std": 34.17632789611817,
#   "hcr_density_coefficients_mean": 0.08400292508304119,
#   "hcr_density_coefficients_std": 51.23813018798828,
#   "hcr_density_state_layers_mean": 0.08200299069285392,
#   "hcr_density_state_layers_std": 71.64267044067383,
#   "hcr_effective_density_coefficients_mean": 0.03878244580700994,
#   "hcr_effective_density_coefficients_std": 37.21740312576294,
#   "hcr_input_density_coefficients_mean": 0.06104882396757603,
# ...

# %%
# !python train.py --config configs/hcr_bidirectional_refinement.yaml
# Out:
# event=start params=3284656 device=cuda model_type=hcr_bidirectional_refinement task=denoising dataset_source=hf://datasets/Trelis/tiny-shakespeare/default/train dataset_chars=1223296 dataset_fallback=False dataset_rows=None dataset_cache_path=data/hf_cache/Trelis_tiny-shakespeare__default__train__auto__1000.txt train_windows=1100838 val_windows=122200
# event=train step=1 loss=4.3902 tokens_per_sec=5182.9910 state_mu_mean=-0.1622 state_mu_std=0.9868 state_log_var_mean=-2.3511 state_log_var_std=1.5718 state_variance_mean=0.5583 state_basis_entropy=0.3149
# event=eval step=1 val_loss=3.8327 val_accuracy=0.1550 val_ece=0.0911 val_brier=0.9462 val_perplexity=46.1891 val_basis_entropy=0.0504 val_log_var_mean=-2.3938 val_log_var_std=1.5146 val_mu_mean=-0.2503 val_mu_std=0.9682 val_variance_mean=0.5155
# ...

# %%
# !python sample.py --checkpoint runs/hcr_bidirectional_refinement/best.pt --prompt "First "

# %%
# !python eval.py --checkpoint runs/hcr_bidirectional_refinement/best.pt

# %%
# !python analyze_uncertainty.py --checkpoint runs/hcr_bidirectional_refinement/best.pt
